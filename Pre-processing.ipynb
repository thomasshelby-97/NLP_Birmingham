# %% [markdown]
# ## Pre-processing using Spacy

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')
# Out:
# D:\Coding\lib\site-packages\spacy\util.py:877: UserWarning: [W095] Model 'en_core_web_sm' (3.4.1) was trained with spaCy v3.4 and may not be 100% compatible with the current version (3.5.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
nlp

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
doc_1 = nlp ('India, a South Asian nation, is the seventh-largest country by area, the second-most populous country with over 1.38 billion people, and the most populous democracy in the world. India boasts of an immensely rich cultural heritage, including numerous languages, traditions, and people. The country holds its uniqueness in its diversity, and hence has adapted itself to international changes with poise and comfort. While the economy has welcomed international companies to invest in it with open arms since liberalisation in the 1990s, Indians have been prudent and proactive in adopting global approaches and skills. Indian villagers have proudly taken up farming, advanced agriculture and unique handicrafts as their profession on one hand, while the modern industries and professional services sectors are coming up in a big way on the other. Thus, the country is attracting many global majors for strategic investments owing to the presence of a vast range of industries, investment avenues and a supportive Government. A huge population, mostly comprising the youth, is a strong driver for demand and an ample source of manpower')

# %%
doc_1
# Out:
# India, a South Asian nation, is the seventh-largest country by area, the second-most populous country with over 1.38 billion people, and the most populous democracy in the world. India boasts of an immensely rich cultural heritage, including numerous languages, traditions, and people. The country holds its uniqueness in its diversity, and hence has adapted itself to international changes with poise and comfort. While the economy has welcomed international companies to invest in it with open arms since liberalisation in the 1990s, Indians have been prudent and proactive in adopting global approaches and skills. Indian villagers have proudly taken up farming, advanced agriculture and unique handicrafts as their profession on one hand, while the modern industries and professional services sectors are coming up in a big way on the other. Thus, the country is attracting many global majors for strategic investments owing to the presence of a vast range of industries, investment avenues and a supportive Government. A huge population, mostly comprising the youth, is a strong driver for demand and an ample source of manpower

# %% [markdown]
# ### Tokenization

# %%
for token in doc_1:
    print (token)
# Out:
# India
# ,
# a
# South
# Asian
# nation
# ,
# is
# the
# seventh
# -
# largest
# country
# by
# area
# ,
# the
# second
# -
# most
# populous
# country
# with
# over
# 1.38
# billion
# people
# ,
# and
# the
# most
# populous
# democracy
# in
# the
# world
# .
# India
# boasts
# of
# an
# immensely
# rich
# cultural
# heritage
# ,
# including
# numerous
# languages
# ,
# traditions
# ,
# and
# people
# .
# The
# country
# holds
# its
# uniqueness
# in
# its
# diversity
# ,
# and
# hence
# has
# adapted
# itself
# to
# international
# changes
# with
# poise
# and
# comfort
# .
# While
# the
# economy
# has
# welcomed
# international
# companies
# to
# invest
# in
# it
# with
# open
# arms
# since
# liberalisation
# in
# the
# 1990s
# ,
# Indians
# have
# been
# prudent
# and
# proactive
# in
# adopting
# global
# approaches
# and
# skills
# .
# Indian
# villagers
# have
# proudly
# taken
# up
# farming
# ,
# advanced
# agriculture
# and
# unique
# handicrafts
# as
# their
# profession
# on
# one
# hand
# ,
# while
# the
# modern
# industries
# and
# professional
# services
# sectors
# are
# coming
# up
# in
# a
# big
# way
# on
# the
# other
# .
# Thus
# ,
# the
# country
# is
# attracting
# many
# global
# majors
# for
# strategic
# investments
# owing
# to
# the
# presence
# of
# a
# vast
# range
# of
# industries
# ,
# investment
# avenues
# and
# a
# supportive
# Government
# .
# A
# huge
# population
# ,
# mostly
# comprising
# the
# youth
# ,
# is
# a
# strong
# driver
# for
# demand
# and
# an
# ample
# source
# of
# manpower

# %%
# Length of the document

len(doc_1)
# Out:
# 200

# %%
# Count of tokens

t_count = 0

for token in doc_1:
    t_count = t_count + 1
print ("The total no of token is:", t_count)
# Out:
# The total no of token is: 200

# %%
from spacy.lang.en.stop_words import STOP_WORDS
print (STOP_WORDS)
# Out:
# {'ourselves', 'see', 'others', 'afterwards', 'bottom', 'hers', 'you', 'yours', 'no', 'still', 'together', 'after', 'against', 'namely', 'so', 'never', 'eleven', 'such', 'perhaps', 'down', 'was', 'wherein', '’d', 'during', 'up', 'not', 'though', 'just', 'although', 'serious', 'why', 'above', 'all', 'well', 'where', 'within', 'many', 'those', 'thus', 'latter', 'somewhere', 'being', 'into', 'call', 'my', 'had', 'third', 'but', "'ll", 'can', 'them', 'almost', 'noone', 'even', 'forty', 'top', "'d", 'himself', 'alone', 'whom', '’ve', 'herein', 'several', 'as', 'six', 'becoming', 'quite', 'seeming', 'seem', 'through', 'they', 'due', 'anywhere', 'she', 'however', 'and', 'two', 'if', 'three', 'me', 'hence', 'whatever', 'some', 'how', 'her', 'name', 'amount', 'are', 'everywhere', "'s", '’m', 'much', 'once', '’ll', 'nobody', 'is', 'in', 'must', 'few', "'m", 'towards', 'really', 'already', 'meanwhile', 'somehow', 'say', 'own', 'go', 'because', 'fifteen', 'nowhere', 'it', 'regarding', 'under', 'across', 'mine', 'every', 'could', 'there', "'ve", 'while', 'might', 'none', 'take', 'indeed', 'beforehand', 'someone', 'n’t', 'whereas', 'make', 'that', 'moreover', 'does', 'wherever', 'without', 'toward', 'until', 'full', 'twenty', 'upon', 'now', 'by', 'something', 'whither', 'along', 'ca', 'at', 'on', 'used', 'only', 'been', 'last', 'would', 'seemed', 'via', 'between', 'anyhow', 'also', 'whereafter', 'any', 'whose', 'elsewhere', 'becomes', 'did', 'five', 'least', 're', 'side', 'here', 'for', 'hereupon', 'from', '‘m', 'i', 'onto', 'front', 'other', 'or', 'out', 'first', 'sometimes', 'four', 'often', 'mostly', 'beside', 'eight', 'when', 'yet', "n't", 'again', 'nine', '‘d', 'anyway', 'thru', 'anyone', 'fifty', 'get', 'n‘t', 'of', 'the', 'less', 'otherwise', 'do', 'done', 'herself', 'then', 'always', 'ours', 'whoever', 'whether', 'itself', 'doing', 'rather', 'than', 'their', 'enough', 'whence', 'everyone', 'over', 'everything', 'one', 'both', 'made', 'cannot', 'may', 'more', 'further', 'whenever', 'per', 'next', 'these', 'give', 'else', 'except', 'hereby', 'am', 'whereupon', 'whole', 'his', 'amongst', 'twelve', 'become', '‘re', 'thereupon', 'thence', 'sixty', 'became', 'ever', 'nor', 'various', 'show', 'we', 'beyond', 'be', '’re', 'us', 'off', 'about', 'a', 'therefore', 'him', 'has', 'throughout', 'our', 'sometime', 'were', 'very', 'hereafter', 'thereby', 'to', 'before', 'former', 'each', 'hundred', 'latterly', 'formerly', 'this', 'behind', 'most', 'among', 'yourself', 'anything', 'besides', 'part', 'should', 'whereby', 'myself', 'an', 'keep', 'seems', 'nothing', 'another', 'themselves', 'what', 'thereafter', 'please', 'below', 'which', 'around', '‘ve', 'using', 'he', 'with', 'move', 'your', 'either', '‘ll', 'yourselves', '’s', "'re", 'ten', 'empty', 'put', 'same', 'will', 'back', 'its', 'who', 'neither', 'have', '‘s', 'too', 'therein', 'since', 'unless', 'nevertheless'}

# %%
# Checking if the tokens are stop words

for token in doc_1:
    print (token, '=====>', token.is_stop)
# Out:
# India =====> False
# , =====> False
# a =====> True
# South =====> False
# Asian =====> False
# nation =====> False
# , =====> False
# is =====> True
# the =====> True
# seventh =====> False
# - =====> False
# largest =====> False
# country =====> False
# by =====> True
# area =====> False
# , =====> False
# the =====> True
# second =====> False
# - =====> False
# most =====> True
# populous =====> False
# country =====> False
# with =====> True
# over =====> True
# 1.38 =====> False
# billion =====> False
# people =====> False
# , =====> False
# and =====> True
# the =====> True
# most =====> True
# populous =====> False
# democracy =====> False
# in =====> True
# the =====> True
# world =====> False
# . =====> False
# India =====> False
# boasts =====> False
# of =====> True
# an =====> True
# immensely =====> False
# rich =====> False
# cultural =====> False
# heritage =====> False
# , =====> False
# including =====> False
# numerous =====> False
# languages =====> False
# , =====> False
# traditions =====> False
# , =====> False
# and =====> True
# people =====> False
# . =====> False
# The =====> True
# country =====> False
# holds =====> False
# its =====> True
# uniqueness =====> False
# in =====> True
# its =====> True
# diversity =====> False
# , =====> False
# and =====> True
# hence =====> True
# has =====> True
# adapted =====> False
# itself =====> True
# to =====> True
# international =====> False
# changes =====> False
# with =====> True
# poise =====> False
# and =====> True
# comfort =====> False
# . =====> False
# While =====> True
# the =====> True
# economy =====> False
# has =====> True
# welcomed =====> False
# international =====> False
# companies =====> False
# to =====> True
# invest =====> False
# in =====> True
# it =====> True
# with =====> True
# open =====> False
# arms =====> False
# since =====> True
# liberalisation =====> False
# in =====> True
# the =====> True
# 1990s =====> False
# , =====> False
# Indians =====> False
# have =====> True
# been =====> True
# prudent =====> False
# and =====> True
# proactive =====> False
# in =====> True
# adopting =====> False
# global =====> False
# approaches =====> False
# and =====> True
# skills =====> False
# . =====> False
# Indian =====> False
# villagers =====> False
# have =====> True
# proudly =====> False
# taken =====> False
# up =====> True
# farming =====> False
# , =====> False
# advanced =====> False
# agriculture =====> False
# and =====> True
# unique =====> False
# handicrafts =====> False
# as =====> True
# their =====> True
# profession =====> False
# on =====> True
# one =====> True
# hand =====> False
# , =====> False
# while =====> True
# the =====> True
# modern =====> False
# industries =====> False
# and =====> True
# professional =====> False
# services =====> False
# sectors =====> False
# are =====> True
# coming =====> False
# up =====> True
# in =====> True
# a =====> True
# big =====> False
# way =====> False
# on =====> True
# the =====> True
# other =====> True
# . =====> False
# Thus =====> True
# , =====> False
# the =====> True
# country =====> False
# is =====> True
# attracting =====> False
# many =====> True
# global =====> False
# majors =====> False
# for =====> True
# strategic =====> False
# investments =====> False
# owing =====> False
# to =====> True
# the =====> True
# presence =====> False
# of =====> True
# a =====> True
# vast =====> False
# range =====> False
# of =====> True
# industries =====> False
# , =====> False
# investment =====> False
# avenues =====> False
# and =====> True
# a =====> True
# supportive =====> False
# Government =====> False
# . =====> False
# A =====> True
# huge =====> False
# population =====> False
# , =====> False
# mostly =====> True
# comprising =====> False
# the =====> True
# youth =====> False
# , =====> False
# is =====> True
# a =====> True
# strong =====> False
# driver =====> False
# for =====> True
# demand =====> False
# and =====> True
# an =====> True
# ample =====> False
# source =====> False
# of =====> True
# manpower =====> False

# %%
# Counting the no of non-stop words

s_count = 0
for token in doc_1:
    if token.is_stop != True:
        s_count = s_count + 1
        print (token)
        
print ('\n The total non-stop words are:', s_count)
# Out:
# India
# ,
# South
# Asian
# nation
# ,
# seventh
# -
# largest
# country
# area
# ,
# second
# -
# populous
# country
# 1.38
# billion
# people
# ,
# populous
# democracy
# world
# .
# India
# boasts
# immensely
# rich
# cultural
# heritage
# ,
# including
# numerous
# languages
# ,
# traditions
# ,
# people
# .
# country
# holds
# uniqueness
# diversity
# ,
# adapted
# international
# changes
# poise
# comfort
# .
# economy
# welcomed
# international
# companies
# invest
# open
# arms
# liberalisation
# 1990s
# ,
# Indians
# prudent
# proactive
# adopting
# global
# approaches
# skills
# .
# Indian
# villagers
# proudly
# taken
# farming
# ,
# advanced
# agriculture
# unique
# handicrafts
# profession
# hand
# ,
# modern
# industries
# professional
# services
# sectors
# coming
# big
# way
# .
# ,
# country
# attracting
# global
# majors
# strategic
# investments
# owing
# presence
# vast
# range
# industries
# ,
# investment
# avenues
# supportive
# Government
# .
# huge
# population
# ,
# comprising
# youth
# ,
# strong
# driver
# demand
# ample
# source
# manpower
#
#  The total non-stop words are: 120

# %%
print ('The total non-stop words are:', s_count)
# Out:
# The total non-stop words are: 120

# %% [markdown]
# ### Checking for punctuation

# %%
# Count of non-punctuation tokens

p_count = 0
for token in doc_1:
    print (token, '======>', token.is_punct)
    print ('\n \n The non-punctuation tokens are:')
    if token.is_punct == False:
        p_count = p_count + 1
        print (token)
print ('\n The total non-punctuation words are:', p_count)
# Out:
# India ======> False
#
#
#  The non-punctuation tokens are:
# India
# , ======> True
#
#
#  The non-punctuation tokens are:
# a ======> False
#
#
#  The non-punctuation tokens are:
# a
# South ======> False
#
#
#  The non-punctuation tokens are:
# South
# Asian ======> False
#
#
#  The non-punctuation tokens are:
# Asian
# nation ======> False
#
#
#  The non-punctuation tokens are:
# nation
# , ======> True
#
#
#  The non-punctuation tokens are:
# is ======> False
#
#
#  The non-punctuation tokens are:
# is
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# seventh ======> False
#
#
#  The non-punctuation tokens are:
# seventh
# - ======> True
#
#
#  The non-punctuation tokens are:
# largest ======> False
#
#
#  The non-punctuation tokens are:
# largest
# country ======> False
#
#
#  The non-punctuation tokens are:
# country
# by ======> False
#
#
#  The non-punctuation tokens are:
# by
# area ======> False
#
#
#  The non-punctuation tokens are:
# area
# , ======> True
#
#
#  The non-punctuation tokens are:
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# second ======> False
#
#
#  The non-punctuation tokens are:
# second
# - ======> True
#
#
#  The non-punctuation tokens are:
# most ======> False
#
#
#  The non-punctuation tokens are:
# most
# populous ======> False
#
#
#  The non-punctuation tokens are:
# populous
# country ======> False
#
#
#  The non-punctuation tokens are:
# country
# with ======> False
#
#
#  The non-punctuation tokens are:
# with
# over ======> False
#
#
#  The non-punctuation tokens are:
# over
# 1.38 ======> False
#
#
#  The non-punctuation tokens are:
# 1.38
# billion ======> False
#
#
#  The non-punctuation tokens are:
# billion
# people ======> False
#
#
#  The non-punctuation tokens are:
# people
# , ======> True
#
#
#  The non-punctuation tokens are:
# and ======> False
#
#
#  The non-punctuation tokens are:
# and
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# most ======> False
#
#
#  The non-punctuation tokens are:
# most
# populous ======> False
#
#
#  The non-punctuation tokens are:
# populous
# democracy ======> False
#
#
#  The non-punctuation tokens are:
# democracy
# in ======> False
#
#
#  The non-punctuation tokens are:
# in
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# world ======> False
#
#
#  The non-punctuation tokens are:
# world
# . ======> True
#
#
#  The non-punctuation tokens are:
# India ======> False
#
#
#  The non-punctuation tokens are:
# India
# boasts ======> False
#
#
#  The non-punctuation tokens are:
# boasts
# of ======> False
#
#
#  The non-punctuation tokens are:
# of
# an ======> False
#
#
#  The non-punctuation tokens are:
# an
# immensely ======> False
#
#
#  The non-punctuation tokens are:
# immensely
# rich ======> False
#
#
#  The non-punctuation tokens are:
# rich
# cultural ======> False
#
#
#  The non-punctuation tokens are:
# cultural
# heritage ======> False
#
#
#  The non-punctuation tokens are:
# heritage
# , ======> True
#
#
#  The non-punctuation tokens are:
# including ======> False
#
#
#  The non-punctuation tokens are:
# including
# numerous ======> False
#
#
#  The non-punctuation tokens are:
# numerous
# languages ======> False
#
#
#  The non-punctuation tokens are:
# languages
# , ======> True
#
#
#  The non-punctuation tokens are:
# traditions ======> False
#
#
#  The non-punctuation tokens are:
# traditions
# , ======> True
#
#
#  The non-punctuation tokens are:
# and ======> False
#
#
#  The non-punctuation tokens are:
# and
# people ======> False
#
#
#  The non-punctuation tokens are:
# people
# . ======> True
#
#
#  The non-punctuation tokens are:
# The ======> False
#
#
#  The non-punctuation tokens are:
# The
# country ======> False
#
#
#  The non-punctuation tokens are:
# country
# holds ======> False
#
#
#  The non-punctuation tokens are:
# holds
# its ======> False
#
#
#  The non-punctuation tokens are:
# its
# uniqueness ======> False
#
#
#  The non-punctuation tokens are:
# uniqueness
# in ======> False
#
#
#  The non-punctuation tokens are:
# in
# its ======> False
#
#
#  The non-punctuation tokens are:
# its
# diversity ======> False
#
#
#  The non-punctuation tokens are:
# diversity
# , ======> True
#
#
#  The non-punctuation tokens are:
# and ======> False
#
#
#  The non-punctuation tokens are:
# and
# hence ======> False
#
#
#  The non-punctuation tokens are:
# hence
# has ======> False
#
#
#  The non-punctuation tokens are:
# has
# adapted ======> False
#
#
#  The non-punctuation tokens are:
# adapted
# itself ======> False
#
#
#  The non-punctuation tokens are:
# itself
# to ======> False
#
#
#  The non-punctuation tokens are:
# to
# international ======> False
#
#
#  The non-punctuation tokens are:
# international
# changes ======> False
#
#
#  The non-punctuation tokens are:
# changes
# with ======> False
#
#
#  The non-punctuation tokens are:
# with
# poise ======> False
#
#
#  The non-punctuation tokens are:
# poise
# and ======> False
#
#
#  The non-punctuation tokens are:
# and
# comfort ======> False
#
#
#  The non-punctuation tokens are:
# comfort
# . ======> True
#
#
#  The non-punctuation tokens are:
# While ======> False
#
#
#  The non-punctuation tokens are:
# While
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# economy ======> False
#
#
#  The non-punctuation tokens are:
# economy
# has ======> False
#
#
#  The non-punctuation tokens are:
# has
# welcomed ======> False
#
#
#  The non-punctuation tokens are:
# welcomed
# international ======> False
#
#
#  The non-punctuation tokens are:
# international
# companies ======> False
#
#
#  The non-punctuation tokens are:
# companies
# to ======> False
#
#
#  The non-punctuation tokens are:
# to
# invest ======> False
#
#
#  The non-punctuation tokens are:
# invest
# in ======> False
#
#
#  The non-punctuation tokens are:
# in
# it ======> False
#
#
#  The non-punctuation tokens are:
# it
# with ======> False
#
#
#  The non-punctuation tokens are:
# with
# open ======> False
#
#
#  The non-punctuation tokens are:
# open
# arms ======> False
#
#
#  The non-punctuation tokens are:
# arms
# since ======> False
#
#
#  The non-punctuation tokens are:
# since
# liberalisation ======> False
#
#
#  The non-punctuation tokens are:
# liberalisation
# in ======> False
#
#
#  The non-punctuation tokens are:
# in
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# 1990s ======> False
#
#
#  The non-punctuation tokens are:
# 1990s
# , ======> True
#
#
#  The non-punctuation tokens are:
# Indians ======> False
#
#
#  The non-punctuation tokens are:
# Indians
# have ======> False
#
#
#  The non-punctuation tokens are:
# have
# been ======> False
#
#
#  The non-punctuation tokens are:
# been
# prudent ======> False
#
#
#  The non-punctuation tokens are:
# prudent
# and ======> False
#
#
#  The non-punctuation tokens are:
# and
# proactive ======> False
#
#
#  The non-punctuation tokens are:
# proactive
# in ======> False
#
#
#  The non-punctuation tokens are:
# in
# adopting ======> False
#
#
#  The non-punctuation tokens are:
# adopting
# global ======> False
#
#
#  The non-punctuation tokens are:
# global
# approaches ======> False
#
#
#  The non-punctuation tokens are:
# approaches
# and ======> False
#
#
#  The non-punctuation tokens are:
# and
# skills ======> False
#
#
#  The non-punctuation tokens are:
# skills
# . ======> True
#
#
#  The non-punctuation tokens are:
# Indian ======> False
#
#
#  The non-punctuation tokens are:
# Indian
# villagers ======> False
#
#
#  The non-punctuation tokens are:
# villagers
# have ======> False
#
#
#  The non-punctuation tokens are:
# have
# proudly ======> False
#
#
#  The non-punctuation tokens are:
# proudly
# taken ======> False
#
#
#  The non-punctuation tokens are:
# taken
# up ======> False
#
#
#  The non-punctuation tokens are:
# up
# farming ======> False
#
#
#  The non-punctuation tokens are:
# farming
# , ======> True
#
#
#  The non-punctuation tokens are:
# advanced ======> False
#
#
#  The non-punctuation tokens are:
# advanced
# agriculture ======> False
#
#
#  The non-punctuation tokens are:
# agriculture
# and ======> False
#
#
#  The non-punctuation tokens are:
# and
# unique ======> False
#
#
#  The non-punctuation tokens are:
# unique
# handicrafts ======> False
#
#
#  The non-punctuation tokens are:
# handicrafts
# as ======> False
#
#
#  The non-punctuation tokens are:
# as
# their ======> False
#
#
#  The non-punctuation tokens are:
# their
# profession ======> False
#
#
#  The non-punctuation tokens are:
# profession
# on ======> False
#
#
#  The non-punctuation tokens are:
# on
# one ======> False
#
#
#  The non-punctuation tokens are:
# one
# hand ======> False
#
#
#  The non-punctuation tokens are:
# hand
# , ======> True
#
#
#  The non-punctuation tokens are:
# while ======> False
#
#
#  The non-punctuation tokens are:
# while
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# modern ======> False
#
#
#  The non-punctuation tokens are:
# modern
# industries ======> False
#
#
#  The non-punctuation tokens are:
# industries
# and ======> False
#
#
#  The non-punctuation tokens are:
# and
# professional ======> False
#
#
#  The non-punctuation tokens are:
# professional
# services ======> False
#
#
#  The non-punctuation tokens are:
# services
# sectors ======> False
#
#
#  The non-punctuation tokens are:
# sectors
# are ======> False
#
#
#  The non-punctuation tokens are:
# are
# coming ======> False
#
#
#  The non-punctuation tokens are:
# coming
# up ======> False
#
#
#  The non-punctuation tokens are:
# up
# in ======> False
#
#
#  The non-punctuation tokens are:
# in
# a ======> False
#
#
#  The non-punctuation tokens are:
# a
# big ======> False
#
#
#  The non-punctuation tokens are:
# big
# way ======> False
#
#
#  The non-punctuation tokens are:
# way
# on ======> False
#
#
#  The non-punctuation tokens are:
# on
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# other ======> False
#
#
#  The non-punctuation tokens are:
# other
# . ======> True
#
#
#  The non-punctuation tokens are:
# Thus ======> False
#
#
#  The non-punctuation tokens are:
# Thus
# , ======> True
#
#
#  The non-punctuation tokens are:
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# country ======> False
#
#
#  The non-punctuation tokens are:
# country
# is ======> False
#
#
#  The non-punctuation tokens are:
# is
# attracting ======> False
#
#
#  The non-punctuation tokens are:
# attracting
# many ======> False
#
#
#  The non-punctuation tokens are:
# many
# global ======> False
#
#
#  The non-punctuation tokens are:
# global
# majors ======> False
#
#
#  The non-punctuation tokens are:
# majors
# for ======> False
#
#
#  The non-punctuation tokens are:
# for
# strategic ======> False
#
#
#  The non-punctuation tokens are:
# strategic
# investments ======> False
#
#
#  The non-punctuation tokens are:
# investments
# owing ======> False
#
#
#  The non-punctuation tokens are:
# owing
# to ======> False
#
#
#  The non-punctuation tokens are:
# to
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# presence ======> False
#
#
#  The non-punctuation tokens are:
# presence
# of ======> False
#
#
#  The non-punctuation tokens are:
# of
# a ======> False
#
#
#  The non-punctuation tokens are:
# a
# vast ======> False
#
#
#  The non-punctuation tokens are:
# vast
# range ======> False
#
#
#  The non-punctuation tokens are:
# range
# of ======> False
#
#
#  The non-punctuation tokens are:
# of
# industries ======> False
#
#
#  The non-punctuation tokens are:
# industries
# , ======> True
#
#
#  The non-punctuation tokens are:
# investment ======> False
#
#
#  The non-punctuation tokens are:
# investment
# avenues ======> False
#
#
#  The non-punctuation tokens are:
# avenues
# and ======> False
#
#
#  The non-punctuation tokens are:
# and
# a ======> False
#
#
#  The non-punctuation tokens are:
# a
# supportive ======> False
#
#
#  The non-punctuation tokens are:
# supportive
# Government ======> False
#
#
#  The non-punctuation tokens are:
# Government
# . ======> True
#
#
#  The non-punctuation tokens are:
# A ======> False
#
#
#  The non-punctuation tokens are:
# A
# huge ======> False
#
#
#  The non-punctuation tokens are:
# huge
# population ======> False
#
#
#  The non-punctuation tokens are:
# population
# , ======> True
#
#
#  The non-punctuation tokens are:
# mostly ======> False
#
#
#  The non-punctuation tokens are:
# mostly
# comprising ======> False
#
#
#  The non-punctuation tokens are:
# comprising
# the ======> False
#
#
#  The non-punctuation tokens are:
# the
# youth ======> False
#
#
#  The non-punctuation tokens are:
# youth
# , ======> True
#
#
#  The non-punctuation tokens are:
# is ======> False
#
#
#  The non-punctuation tokens are:
# is
# a ======> False
#
#
#  The non-punctuation tokens are:
# a
# strong ======> False
#
#
#  The non-punctuation tokens are:
# strong
# driver ======> False
#
#
#  The non-punctuation tokens are:
# driver
# for ======> False
#
#
#  The non-punctuation tokens are:
# for
# demand ======> False
#
#
#  The non-punctuation tokens are:
# demand
# and ======> False
#
#
#  The non-punctuation tokens are:
# and
# an ======> False
#
#
#  The non-punctuation tokens are:
# an
# ample ======> False
#
#
#  The non-punctuation tokens are:
# ample
# source ======> False
#
#
#  The non-punctuation tokens are:
# source
# of ======> False
#
#
#  The non-punctuation tokens are:
# of
# manpower ======> False
#
#
#  The non-punctuation tokens are:
# manpower
#
#  The total non-punctuation words are: 177

# %%
# Count of punctuation tokens

pu_count = 0
for token in doc_1:
    print (token, '======>', token.is_punct)
    print ('\n \n The punctuation tokens are:')
    if token.is_punct == True:
        pu_count = pu_count + 1
        print (token)
print ('\n The total non-punctuation words are:', pu_count)
# Out:
# India ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# a ======> False
#
#
#  The punctuation tokens are:
# South ======> False
#
#
#  The punctuation tokens are:
# Asian ======> False
#
#
#  The punctuation tokens are:
# nation ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# is ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# seventh ======> False
#
#
#  The punctuation tokens are:
# - ======> True
#
#
#  The punctuation tokens are:
# -
# largest ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# by ======> False
#
#
#  The punctuation tokens are:
# area ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# the ======> False
#
#
#  The punctuation tokens are:
# second ======> False
#
#
#  The punctuation tokens are:
# - ======> True
#
#
#  The punctuation tokens are:
# -
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# over ======> False
#
#
#  The punctuation tokens are:
# 1.38 ======> False
#
#
#  The punctuation tokens are:
# billion ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# and ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# democracy ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# world ======> False
#
#
#  The punctuation tokens are:
# . ======> True
#
#
#  The punctuation tokens are:
# .
# India ======> False
#
#
#  The punctuation tokens are:
# boasts ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# immensely ======> False
#
#
#  The punctuation tokens are:
# rich ======> False
#
#
#  The punctuation tokens are:
# cultural ======> False
#
#
#  The punctuation tokens are:
# heritage ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# including ======> False
#
#
#  The punctuation tokens are:
# numerous ======> False
#
#
#  The punctuation tokens are:
# languages ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# traditions ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# and ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# . ======> True
#
#
#  The punctuation tokens are:
# .
# The ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# holds ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# uniqueness ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# diversity ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# and ======> False
#
#
#  The punctuation tokens are:
# hence ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# adapted ======> False
#
#
#  The punctuation tokens are:
# itself ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# changes ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# poise ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# comfort ======> False
#
#
#  The punctuation tokens are:
# . ======> True
#
#
#  The punctuation tokens are:
# .
# While ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# economy ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# welcomed ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# companies ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# invest ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# it ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# open ======> False
#
#
#  The punctuation tokens are:
# arms ======> False
#
#
#  The punctuation tokens are:
# since ======> False
#
#
#  The punctuation tokens are:
# liberalisation ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# 1990s ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# Indians ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# been ======> False
#
#
#  The punctuation tokens are:
# prudent ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# proactive ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# adopting ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# approaches ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# skills ======> False
#
#
#  The punctuation tokens are:
# . ======> True
#
#
#  The punctuation tokens are:
# .
# Indian ======> False
#
#
#  The punctuation tokens are:
# villagers ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# proudly ======> False
#
#
#  The punctuation tokens are:
# taken ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# farming ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# advanced ======> False
#
#
#  The punctuation tokens are:
# agriculture ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# unique ======> False
#
#
#  The punctuation tokens are:
# handicrafts ======> False
#
#
#  The punctuation tokens are:
# as ======> False
#
#
#  The punctuation tokens are:
# their ======> False
#
#
#  The punctuation tokens are:
# profession ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# one ======> False
#
#
#  The punctuation tokens are:
# hand ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# while ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# modern ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# professional ======> False
#
#
#  The punctuation tokens are:
# services ======> False
#
#
#  The punctuation tokens are:
# sectors ======> False
#
#
#  The punctuation tokens are:
# are ======> False
#
#
#  The punctuation tokens are:
# coming ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# big ======> False
#
#
#  The punctuation tokens are:
# way ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# other ======> False
#
#
#  The punctuation tokens are:
# . ======> True
#
#
#  The punctuation tokens are:
# .
# Thus ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# the ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# attracting ======> False
#
#
#  The punctuation tokens are:
# many ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# majors ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# strategic ======> False
#
#
#  The punctuation tokens are:
# investments ======> False
#
#
#  The punctuation tokens are:
# owing ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# presence ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# vast ======> False
#
#
#  The punctuation tokens are:
# range ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# investment ======> False
#
#
#  The punctuation tokens are:
# avenues ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# supportive ======> False
#
#
#  The punctuation tokens are:
# Government ======> False
#
#
#  The punctuation tokens are:
# . ======> True
#
#
#  The punctuation tokens are:
# .
# A ======> False
#
#
#  The punctuation tokens are:
# huge ======> False
#
#
#  The punctuation tokens are:
# population ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# mostly ======> False
#
#
#  The punctuation tokens are:
# comprising ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# youth ======> False
#
#
#  The punctuation tokens are:
# , ======> True
#
#
#  The punctuation tokens are:
# ,
# is ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# strong ======> False
#
#
#  The punctuation tokens are:
# driver ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# demand ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# ample ======> False
#
#
#  The punctuation tokens are:
# source ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# manpower ======> False
#
#
#  The punctuation tokens are:
#
#  The total non-punctuation words are: 23

# %%
# Count of left punctuation tokens

left_p_count = 0
for token in doc_1:
    print (token, '======>', token.is_left_punct)
    print ('\n \n The punctuation tokens are:')
    if token.is_left_punct == True:
        left_p_count = left_p_count + 1
        print (token)
print ('\n The total non-punctuation words are:', left_p_count)
# Out:
# India ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# South ======> False
#
#
#  The punctuation tokens are:
# Asian ======> False
#
#
#  The punctuation tokens are:
# nation ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# seventh ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# largest ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# by ======> False
#
#
#  The punctuation tokens are:
# area ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# second ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# over ======> False
#
#
#  The punctuation tokens are:
# 1.38 ======> False
#
#
#  The punctuation tokens are:
# billion ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# democracy ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# world ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# India ======> False
#
#
#  The punctuation tokens are:
# boasts ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# immensely ======> False
#
#
#  The punctuation tokens are:
# rich ======> False
#
#
#  The punctuation tokens are:
# cultural ======> False
#
#
#  The punctuation tokens are:
# heritage ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# including ======> False
#
#
#  The punctuation tokens are:
# numerous ======> False
#
#
#  The punctuation tokens are:
# languages ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# traditions ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# The ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# holds ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# uniqueness ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# diversity ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# hence ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# adapted ======> False
#
#
#  The punctuation tokens are:
# itself ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# changes ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# poise ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# comfort ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# While ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# economy ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# welcomed ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# companies ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# invest ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# it ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# open ======> False
#
#
#  The punctuation tokens are:
# arms ======> False
#
#
#  The punctuation tokens are:
# since ======> False
#
#
#  The punctuation tokens are:
# liberalisation ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# 1990s ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# Indians ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# been ======> False
#
#
#  The punctuation tokens are:
# prudent ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# proactive ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# adopting ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# approaches ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# skills ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Indian ======> False
#
#
#  The punctuation tokens are:
# villagers ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# proudly ======> False
#
#
#  The punctuation tokens are:
# taken ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# farming ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# advanced ======> False
#
#
#  The punctuation tokens are:
# agriculture ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# unique ======> False
#
#
#  The punctuation tokens are:
# handicrafts ======> False
#
#
#  The punctuation tokens are:
# as ======> False
#
#
#  The punctuation tokens are:
# their ======> False
#
#
#  The punctuation tokens are:
# profession ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# one ======> False
#
#
#  The punctuation tokens are:
# hand ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# while ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# modern ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# professional ======> False
#
#
#  The punctuation tokens are:
# services ======> False
#
#
#  The punctuation tokens are:
# sectors ======> False
#
#
#  The punctuation tokens are:
# are ======> False
#
#
#  The punctuation tokens are:
# coming ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# big ======> False
#
#
#  The punctuation tokens are:
# way ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# other ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Thus ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# attracting ======> False
#
#
#  The punctuation tokens are:
# many ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# majors ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# strategic ======> False
#
#
#  The punctuation tokens are:
# investments ======> False
#
#
#  The punctuation tokens are:
# owing ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# presence ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# vast ======> False
#
#
#  The punctuation tokens are:
# range ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# investment ======> False
#
#
#  The punctuation tokens are:
# avenues ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# supportive ======> False
#
#
#  The punctuation tokens are:
# Government ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# A ======> False
#
#
#  The punctuation tokens are:
# huge ======> False
#
#
#  The punctuation tokens are:
# population ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# mostly ======> False
#
#
#  The punctuation tokens are:
# comprising ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# youth ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# strong ======> False
#
#
#  The punctuation tokens are:
# driver ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# demand ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# ample ======> False
#
#
#  The punctuation tokens are:
# source ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# manpower ======> False
#
#
#  The punctuation tokens are:
#
#  The total non-punctuation words are: 0

# %%
# Count of right punctuation tokens

right_p_count = 0
for token in doc_1:
    print (token, '======>', token.is_right_punct)
    print ('\n \n The punctuation tokens are:')
    if token.is_right_punct == True:
        right_p_count = right_p_count + 1
        print (token)
print ('\n The total non-punctuation words are:', right_p_count)
# Out:
# India ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# South ======> False
#
#
#  The punctuation tokens are:
# Asian ======> False
#
#
#  The punctuation tokens are:
# nation ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# seventh ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# largest ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# by ======> False
#
#
#  The punctuation tokens are:
# area ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# second ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# over ======> False
#
#
#  The punctuation tokens are:
# 1.38 ======> False
#
#
#  The punctuation tokens are:
# billion ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# democracy ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# world ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# India ======> False
#
#
#  The punctuation tokens are:
# boasts ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# immensely ======> False
#
#
#  The punctuation tokens are:
# rich ======> False
#
#
#  The punctuation tokens are:
# cultural ======> False
#
#
#  The punctuation tokens are:
# heritage ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# including ======> False
#
#
#  The punctuation tokens are:
# numerous ======> False
#
#
#  The punctuation tokens are:
# languages ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# traditions ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# The ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# holds ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# uniqueness ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# diversity ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# hence ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# adapted ======> False
#
#
#  The punctuation tokens are:
# itself ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# changes ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# poise ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# comfort ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# While ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# economy ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# welcomed ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# companies ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# invest ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# it ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# open ======> False
#
#
#  The punctuation tokens are:
# arms ======> False
#
#
#  The punctuation tokens are:
# since ======> False
#
#
#  The punctuation tokens are:
# liberalisation ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# 1990s ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# Indians ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# been ======> False
#
#
#  The punctuation tokens are:
# prudent ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# proactive ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# adopting ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# approaches ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# skills ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Indian ======> False
#
#
#  The punctuation tokens are:
# villagers ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# proudly ======> False
#
#
#  The punctuation tokens are:
# taken ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# farming ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# advanced ======> False
#
#
#  The punctuation tokens are:
# agriculture ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# unique ======> False
#
#
#  The punctuation tokens are:
# handicrafts ======> False
#
#
#  The punctuation tokens are:
# as ======> False
#
#
#  The punctuation tokens are:
# their ======> False
#
#
#  The punctuation tokens are:
# profession ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# one ======> False
#
#
#  The punctuation tokens are:
# hand ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# while ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# modern ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# professional ======> False
#
#
#  The punctuation tokens are:
# services ======> False
#
#
#  The punctuation tokens are:
# sectors ======> False
#
#
#  The punctuation tokens are:
# are ======> False
#
#
#  The punctuation tokens are:
# coming ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# big ======> False
#
#
#  The punctuation tokens are:
# way ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# other ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Thus ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# attracting ======> False
#
#
#  The punctuation tokens are:
# many ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# majors ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# strategic ======> False
#
#
#  The punctuation tokens are:
# investments ======> False
#
#
#  The punctuation tokens are:
# owing ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# presence ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# vast ======> False
#
#
#  The punctuation tokens are:
# range ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# investment ======> False
#
#
#  The punctuation tokens are:
# avenues ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# supportive ======> False
#
#
#  The punctuation tokens are:
# Government ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# A ======> False
#
#
#  The punctuation tokens are:
# huge ======> False
#
#
#  The punctuation tokens are:
# population ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# mostly ======> False
#
#
#  The punctuation tokens are:
# comprising ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# youth ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# strong ======> False
#
#
#  The punctuation tokens are:
# driver ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# demand ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# ample ======> False
#
#
#  The punctuation tokens are:
# source ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# manpower ======> False
#
#
#  The punctuation tokens are:
#
#  The total non-punctuation words are: 0

# %% [markdown]
# ### Checking for an alphabet

# %%
# Count of alphabetical tokens

a_count = 0
for token in doc_1:
    print (token, '======>', token.is_alpha)
    print ('\n \n The punctuation tokens are:')
    if token.is_alpha == True:
        a_count = a_count + 1
        print (token)
print ('\n The total non-punctuation words are:', a_count)
# Out:
# India ======> True
#
#
#  The punctuation tokens are:
# India
# , ======> False
#
#
#  The punctuation tokens are:
# a ======> True
#
#
#  The punctuation tokens are:
# a
# South ======> True
#
#
#  The punctuation tokens are:
# South
# Asian ======> True
#
#
#  The punctuation tokens are:
# Asian
# nation ======> True
#
#
#  The punctuation tokens are:
# nation
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> True
#
#
#  The punctuation tokens are:
# is
# the ======> True
#
#
#  The punctuation tokens are:
# the
# seventh ======> True
#
#
#  The punctuation tokens are:
# seventh
# - ======> False
#
#
#  The punctuation tokens are:
# largest ======> True
#
#
#  The punctuation tokens are:
# largest
# country ======> True
#
#
#  The punctuation tokens are:
# country
# by ======> True
#
#
#  The punctuation tokens are:
# by
# area ======> True
#
#
#  The punctuation tokens are:
# area
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> True
#
#
#  The punctuation tokens are:
# the
# second ======> True
#
#
#  The punctuation tokens are:
# second
# - ======> False
#
#
#  The punctuation tokens are:
# most ======> True
#
#
#  The punctuation tokens are:
# most
# populous ======> True
#
#
#  The punctuation tokens are:
# populous
# country ======> True
#
#
#  The punctuation tokens are:
# country
# with ======> True
#
#
#  The punctuation tokens are:
# with
# over ======> True
#
#
#  The punctuation tokens are:
# over
# 1.38 ======> False
#
#
#  The punctuation tokens are:
# billion ======> True
#
#
#  The punctuation tokens are:
# billion
# people ======> True
#
#
#  The punctuation tokens are:
# people
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> True
#
#
#  The punctuation tokens are:
# and
# the ======> True
#
#
#  The punctuation tokens are:
# the
# most ======> True
#
#
#  The punctuation tokens are:
# most
# populous ======> True
#
#
#  The punctuation tokens are:
# populous
# democracy ======> True
#
#
#  The punctuation tokens are:
# democracy
# in ======> True
#
#
#  The punctuation tokens are:
# in
# the ======> True
#
#
#  The punctuation tokens are:
# the
# world ======> True
#
#
#  The punctuation tokens are:
# world
# . ======> False
#
#
#  The punctuation tokens are:
# India ======> True
#
#
#  The punctuation tokens are:
# India
# boasts ======> True
#
#
#  The punctuation tokens are:
# boasts
# of ======> True
#
#
#  The punctuation tokens are:
# of
# an ======> True
#
#
#  The punctuation tokens are:
# an
# immensely ======> True
#
#
#  The punctuation tokens are:
# immensely
# rich ======> True
#
#
#  The punctuation tokens are:
# rich
# cultural ======> True
#
#
#  The punctuation tokens are:
# cultural
# heritage ======> True
#
#
#  The punctuation tokens are:
# heritage
# , ======> False
#
#
#  The punctuation tokens are:
# including ======> True
#
#
#  The punctuation tokens are:
# including
# numerous ======> True
#
#
#  The punctuation tokens are:
# numerous
# languages ======> True
#
#
#  The punctuation tokens are:
# languages
# , ======> False
#
#
#  The punctuation tokens are:
# traditions ======> True
#
#
#  The punctuation tokens are:
# traditions
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> True
#
#
#  The punctuation tokens are:
# and
# people ======> True
#
#
#  The punctuation tokens are:
# people
# . ======> False
#
#
#  The punctuation tokens are:
# The ======> True
#
#
#  The punctuation tokens are:
# The
# country ======> True
#
#
#  The punctuation tokens are:
# country
# holds ======> True
#
#
#  The punctuation tokens are:
# holds
# its ======> True
#
#
#  The punctuation tokens are:
# its
# uniqueness ======> True
#
#
#  The punctuation tokens are:
# uniqueness
# in ======> True
#
#
#  The punctuation tokens are:
# in
# its ======> True
#
#
#  The punctuation tokens are:
# its
# diversity ======> True
#
#
#  The punctuation tokens are:
# diversity
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> True
#
#
#  The punctuation tokens are:
# and
# hence ======> True
#
#
#  The punctuation tokens are:
# hence
# has ======> True
#
#
#  The punctuation tokens are:
# has
# adapted ======> True
#
#
#  The punctuation tokens are:
# adapted
# itself ======> True
#
#
#  The punctuation tokens are:
# itself
# to ======> True
#
#
#  The punctuation tokens are:
# to
# international ======> True
#
#
#  The punctuation tokens are:
# international
# changes ======> True
#
#
#  The punctuation tokens are:
# changes
# with ======> True
#
#
#  The punctuation tokens are:
# with
# poise ======> True
#
#
#  The punctuation tokens are:
# poise
# and ======> True
#
#
#  The punctuation tokens are:
# and
# comfort ======> True
#
#
#  The punctuation tokens are:
# comfort
# . ======> False
#
#
#  The punctuation tokens are:
# While ======> True
#
#
#  The punctuation tokens are:
# While
# the ======> True
#
#
#  The punctuation tokens are:
# the
# economy ======> True
#
#
#  The punctuation tokens are:
# economy
# has ======> True
#
#
#  The punctuation tokens are:
# has
# welcomed ======> True
#
#
#  The punctuation tokens are:
# welcomed
# international ======> True
#
#
#  The punctuation tokens are:
# international
# companies ======> True
#
#
#  The punctuation tokens are:
# companies
# to ======> True
#
#
#  The punctuation tokens are:
# to
# invest ======> True
#
#
#  The punctuation tokens are:
# invest
# in ======> True
#
#
#  The punctuation tokens are:
# in
# it ======> True
#
#
#  The punctuation tokens are:
# it
# with ======> True
#
#
#  The punctuation tokens are:
# with
# open ======> True
#
#
#  The punctuation tokens are:
# open
# arms ======> True
#
#
#  The punctuation tokens are:
# arms
# since ======> True
#
#
#  The punctuation tokens are:
# since
# liberalisation ======> True
#
#
#  The punctuation tokens are:
# liberalisation
# in ======> True
#
#
#  The punctuation tokens are:
# in
# the ======> True
#
#
#  The punctuation tokens are:
# the
# 1990s ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# Indians ======> True
#
#
#  The punctuation tokens are:
# Indians
# have ======> True
#
#
#  The punctuation tokens are:
# have
# been ======> True
#
#
#  The punctuation tokens are:
# been
# prudent ======> True
#
#
#  The punctuation tokens are:
# prudent
# and ======> True
#
#
#  The punctuation tokens are:
# and
# proactive ======> True
#
#
#  The punctuation tokens are:
# proactive
# in ======> True
#
#
#  The punctuation tokens are:
# in
# adopting ======> True
#
#
#  The punctuation tokens are:
# adopting
# global ======> True
#
#
#  The punctuation tokens are:
# global
# approaches ======> True
#
#
#  The punctuation tokens are:
# approaches
# and ======> True
#
#
#  The punctuation tokens are:
# and
# skills ======> True
#
#
#  The punctuation tokens are:
# skills
# . ======> False
#
#
#  The punctuation tokens are:
# Indian ======> True
#
#
#  The punctuation tokens are:
# Indian
# villagers ======> True
#
#
#  The punctuation tokens are:
# villagers
# have ======> True
#
#
#  The punctuation tokens are:
# have
# proudly ======> True
#
#
#  The punctuation tokens are:
# proudly
# taken ======> True
#
#
#  The punctuation tokens are:
# taken
# up ======> True
#
#
#  The punctuation tokens are:
# up
# farming ======> True
#
#
#  The punctuation tokens are:
# farming
# , ======> False
#
#
#  The punctuation tokens are:
# advanced ======> True
#
#
#  The punctuation tokens are:
# advanced
# agriculture ======> True
#
#
#  The punctuation tokens are:
# agriculture
# and ======> True
#
#
#  The punctuation tokens are:
# and
# unique ======> True
#
#
#  The punctuation tokens are:
# unique
# handicrafts ======> True
#
#
#  The punctuation tokens are:
# handicrafts
# as ======> True
#
#
#  The punctuation tokens are:
# as
# their ======> True
#
#
#  The punctuation tokens are:
# their
# profession ======> True
#
#
#  The punctuation tokens are:
# profession
# on ======> True
#
#
#  The punctuation tokens are:
# on
# one ======> True
#
#
#  The punctuation tokens are:
# one
# hand ======> True
#
#
#  The punctuation tokens are:
# hand
# , ======> False
#
#
#  The punctuation tokens are:
# while ======> True
#
#
#  The punctuation tokens are:
# while
# the ======> True
#
#
#  The punctuation tokens are:
# the
# modern ======> True
#
#
#  The punctuation tokens are:
# modern
# industries ======> True
#
#
#  The punctuation tokens are:
# industries
# and ======> True
#
#
#  The punctuation tokens are:
# and
# professional ======> True
#
#
#  The punctuation tokens are:
# professional
# services ======> True
#
#
#  The punctuation tokens are:
# services
# sectors ======> True
#
#
#  The punctuation tokens are:
# sectors
# are ======> True
#
#
#  The punctuation tokens are:
# are
# coming ======> True
#
#
#  The punctuation tokens are:
# coming
# up ======> True
#
#
#  The punctuation tokens are:
# up
# in ======> True
#
#
#  The punctuation tokens are:
# in
# a ======> True
#
#
#  The punctuation tokens are:
# a
# big ======> True
#
#
#  The punctuation tokens are:
# big
# way ======> True
#
#
#  The punctuation tokens are:
# way
# on ======> True
#
#
#  The punctuation tokens are:
# on
# the ======> True
#
#
#  The punctuation tokens are:
# the
# other ======> True
#
#
#  The punctuation tokens are:
# other
# . ======> False
#
#
#  The punctuation tokens are:
# Thus ======> True
#
#
#  The punctuation tokens are:
# Thus
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> True
#
#
#  The punctuation tokens are:
# the
# country ======> True
#
#
#  The punctuation tokens are:
# country
# is ======> True
#
#
#  The punctuation tokens are:
# is
# attracting ======> True
#
#
#  The punctuation tokens are:
# attracting
# many ======> True
#
#
#  The punctuation tokens are:
# many
# global ======> True
#
#
#  The punctuation tokens are:
# global
# majors ======> True
#
#
#  The punctuation tokens are:
# majors
# for ======> True
#
#
#  The punctuation tokens are:
# for
# strategic ======> True
#
#
#  The punctuation tokens are:
# strategic
# investments ======> True
#
#
#  The punctuation tokens are:
# investments
# owing ======> True
#
#
#  The punctuation tokens are:
# owing
# to ======> True
#
#
#  The punctuation tokens are:
# to
# the ======> True
#
#
#  The punctuation tokens are:
# the
# presence ======> True
#
#
#  The punctuation tokens are:
# presence
# of ======> True
#
#
#  The punctuation tokens are:
# of
# a ======> True
#
#
#  The punctuation tokens are:
# a
# vast ======> True
#
#
#  The punctuation tokens are:
# vast
# range ======> True
#
#
#  The punctuation tokens are:
# range
# of ======> True
#
#
#  The punctuation tokens are:
# of
# industries ======> True
#
#
#  The punctuation tokens are:
# industries
# , ======> False
#
#
#  The punctuation tokens are:
# investment ======> True
#
#
#  The punctuation tokens are:
# investment
# avenues ======> True
#
#
#  The punctuation tokens are:
# avenues
# and ======> True
#
#
#  The punctuation tokens are:
# and
# a ======> True
#
#
#  The punctuation tokens are:
# a
# supportive ======> True
#
#
#  The punctuation tokens are:
# supportive
# Government ======> True
#
#
#  The punctuation tokens are:
# Government
# . ======> False
#
#
#  The punctuation tokens are:
# A ======> True
#
#
#  The punctuation tokens are:
# A
# huge ======> True
#
#
#  The punctuation tokens are:
# huge
# population ======> True
#
#
#  The punctuation tokens are:
# population
# , ======> False
#
#
#  The punctuation tokens are:
# mostly ======> True
#
#
#  The punctuation tokens are:
# mostly
# comprising ======> True
#
#
#  The punctuation tokens are:
# comprising
# the ======> True
#
#
#  The punctuation tokens are:
# the
# youth ======> True
#
#
#  The punctuation tokens are:
# youth
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> True
#
#
#  The punctuation tokens are:
# is
# a ======> True
#
#
#  The punctuation tokens are:
# a
# strong ======> True
#
#
#  The punctuation tokens are:
# strong
# driver ======> True
#
#
#  The punctuation tokens are:
# driver
# for ======> True
#
#
#  The punctuation tokens are:
# for
# demand ======> True
#
#
#  The punctuation tokens are:
# demand
# and ======> True
#
#
#  The punctuation tokens are:
# and
# an ======> True
#
#
#  The punctuation tokens are:
# an
# ample ======> True
#
#
#  The punctuation tokens are:
# ample
# source ======> True
#
#
#  The punctuation tokens are:
# source
# of ======> True
#
#
#  The punctuation tokens are:
# of
# manpower ======> True
#
#
#  The punctuation tokens are:
# manpower
#
#  The total non-punctuation words are: 175

# %% [markdown]
# ### Checking for digit tokens

# %%
# Count of digit tokens

d_count = 0
for token in doc_1:
    print (token, '======>', token.is_digit)
    print ('\n \n The punctuation tokens are:')
    if token.is_digit == True:
        d_count = d_count + 1
        print (token)
print ('\n The total non-punctuation words are:', d_count)
# Out:
# India ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# South ======> False
#
#
#  The punctuation tokens are:
# Asian ======> False
#
#
#  The punctuation tokens are:
# nation ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# seventh ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# largest ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# by ======> False
#
#
#  The punctuation tokens are:
# area ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# second ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# over ======> False
#
#
#  The punctuation tokens are:
# 1.38 ======> False
#
#
#  The punctuation tokens are:
# billion ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# democracy ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# world ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# India ======> False
#
#
#  The punctuation tokens are:
# boasts ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# immensely ======> False
#
#
#  The punctuation tokens are:
# rich ======> False
#
#
#  The punctuation tokens are:
# cultural ======> False
#
#
#  The punctuation tokens are:
# heritage ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# including ======> False
#
#
#  The punctuation tokens are:
# numerous ======> False
#
#
#  The punctuation tokens are:
# languages ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# traditions ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# The ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# holds ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# uniqueness ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# diversity ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# hence ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# adapted ======> False
#
#
#  The punctuation tokens are:
# itself ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# changes ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# poise ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# comfort ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# While ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# economy ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# welcomed ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# companies ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# invest ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# it ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# open ======> False
#
#
#  The punctuation tokens are:
# arms ======> False
#
#
#  The punctuation tokens are:
# since ======> False
#
#
#  The punctuation tokens are:
# liberalisation ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# 1990s ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# Indians ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# been ======> False
#
#
#  The punctuation tokens are:
# prudent ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# proactive ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# adopting ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# approaches ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# skills ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Indian ======> False
#
#
#  The punctuation tokens are:
# villagers ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# proudly ======> False
#
#
#  The punctuation tokens are:
# taken ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# farming ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# advanced ======> False
#
#
#  The punctuation tokens are:
# agriculture ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# unique ======> False
#
#
#  The punctuation tokens are:
# handicrafts ======> False
#
#
#  The punctuation tokens are:
# as ======> False
#
#
#  The punctuation tokens are:
# their ======> False
#
#
#  The punctuation tokens are:
# profession ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# one ======> False
#
#
#  The punctuation tokens are:
# hand ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# while ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# modern ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# professional ======> False
#
#
#  The punctuation tokens are:
# services ======> False
#
#
#  The punctuation tokens are:
# sectors ======> False
#
#
#  The punctuation tokens are:
# are ======> False
#
#
#  The punctuation tokens are:
# coming ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# big ======> False
#
#
#  The punctuation tokens are:
# way ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# other ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Thus ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# attracting ======> False
#
#
#  The punctuation tokens are:
# many ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# majors ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# strategic ======> False
#
#
#  The punctuation tokens are:
# investments ======> False
#
#
#  The punctuation tokens are:
# owing ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# presence ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# vast ======> False
#
#
#  The punctuation tokens are:
# range ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# investment ======> False
#
#
#  The punctuation tokens are:
# avenues ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# supportive ======> False
#
#
#  The punctuation tokens are:
# Government ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# A ======> False
#
#
#  The punctuation tokens are:
# huge ======> False
#
#
#  The punctuation tokens are:
# population ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# mostly ======> False
#
#
#  The punctuation tokens are:
# comprising ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# youth ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# strong ======> False
#
#
#  The punctuation tokens are:
# driver ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# demand ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# ample ======> False
#
#
#  The punctuation tokens are:
# source ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# manpower ======> False
#
#
#  The punctuation tokens are:
#
#  The total non-punctuation words are: 0

# %%
doc_2 = nlp('10000 is a big number')
for token in doc_2:
    print (token, '====>', token.is_digit)
# Out:
# 10000 ====> True
# is ====> False
# a ====> False
# big ====> False
# number ====> False

# %% [markdown]
# ### Checking for lower case tokens

# %%
# Count of lower case tokens

low_count = 0
for token in doc_1:
    print (token, '======>', token.is_lower)
    print ('\n \n The punctuation tokens are:')
    if token.is_lower == True:
        low_count = low_count + 1
        print (token)
print ('\n The total non-punctuation words are:', low_count)
# Out:
# India ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# a ======> True
#
#
#  The punctuation tokens are:
# a
# South ======> False
#
#
#  The punctuation tokens are:
# Asian ======> False
#
#
#  The punctuation tokens are:
# nation ======> True
#
#
#  The punctuation tokens are:
# nation
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> True
#
#
#  The punctuation tokens are:
# is
# the ======> True
#
#
#  The punctuation tokens are:
# the
# seventh ======> True
#
#
#  The punctuation tokens are:
# seventh
# - ======> False
#
#
#  The punctuation tokens are:
# largest ======> True
#
#
#  The punctuation tokens are:
# largest
# country ======> True
#
#
#  The punctuation tokens are:
# country
# by ======> True
#
#
#  The punctuation tokens are:
# by
# area ======> True
#
#
#  The punctuation tokens are:
# area
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> True
#
#
#  The punctuation tokens are:
# the
# second ======> True
#
#
#  The punctuation tokens are:
# second
# - ======> False
#
#
#  The punctuation tokens are:
# most ======> True
#
#
#  The punctuation tokens are:
# most
# populous ======> True
#
#
#  The punctuation tokens are:
# populous
# country ======> True
#
#
#  The punctuation tokens are:
# country
# with ======> True
#
#
#  The punctuation tokens are:
# with
# over ======> True
#
#
#  The punctuation tokens are:
# over
# 1.38 ======> False
#
#
#  The punctuation tokens are:
# billion ======> True
#
#
#  The punctuation tokens are:
# billion
# people ======> True
#
#
#  The punctuation tokens are:
# people
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> True
#
#
#  The punctuation tokens are:
# and
# the ======> True
#
#
#  The punctuation tokens are:
# the
# most ======> True
#
#
#  The punctuation tokens are:
# most
# populous ======> True
#
#
#  The punctuation tokens are:
# populous
# democracy ======> True
#
#
#  The punctuation tokens are:
# democracy
# in ======> True
#
#
#  The punctuation tokens are:
# in
# the ======> True
#
#
#  The punctuation tokens are:
# the
# world ======> True
#
#
#  The punctuation tokens are:
# world
# . ======> False
#
#
#  The punctuation tokens are:
# India ======> False
#
#
#  The punctuation tokens are:
# boasts ======> True
#
#
#  The punctuation tokens are:
# boasts
# of ======> True
#
#
#  The punctuation tokens are:
# of
# an ======> True
#
#
#  The punctuation tokens are:
# an
# immensely ======> True
#
#
#  The punctuation tokens are:
# immensely
# rich ======> True
#
#
#  The punctuation tokens are:
# rich
# cultural ======> True
#
#
#  The punctuation tokens are:
# cultural
# heritage ======> True
#
#
#  The punctuation tokens are:
# heritage
# , ======> False
#
#
#  The punctuation tokens are:
# including ======> True
#
#
#  The punctuation tokens are:
# including
# numerous ======> True
#
#
#  The punctuation tokens are:
# numerous
# languages ======> True
#
#
#  The punctuation tokens are:
# languages
# , ======> False
#
#
#  The punctuation tokens are:
# traditions ======> True
#
#
#  The punctuation tokens are:
# traditions
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> True
#
#
#  The punctuation tokens are:
# and
# people ======> True
#
#
#  The punctuation tokens are:
# people
# . ======> False
#
#
#  The punctuation tokens are:
# The ======> False
#
#
#  The punctuation tokens are:
# country ======> True
#
#
#  The punctuation tokens are:
# country
# holds ======> True
#
#
#  The punctuation tokens are:
# holds
# its ======> True
#
#
#  The punctuation tokens are:
# its
# uniqueness ======> True
#
#
#  The punctuation tokens are:
# uniqueness
# in ======> True
#
#
#  The punctuation tokens are:
# in
# its ======> True
#
#
#  The punctuation tokens are:
# its
# diversity ======> True
#
#
#  The punctuation tokens are:
# diversity
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> True
#
#
#  The punctuation tokens are:
# and
# hence ======> True
#
#
#  The punctuation tokens are:
# hence
# has ======> True
#
#
#  The punctuation tokens are:
# has
# adapted ======> True
#
#
#  The punctuation tokens are:
# adapted
# itself ======> True
#
#
#  The punctuation tokens are:
# itself
# to ======> True
#
#
#  The punctuation tokens are:
# to
# international ======> True
#
#
#  The punctuation tokens are:
# international
# changes ======> True
#
#
#  The punctuation tokens are:
# changes
# with ======> True
#
#
#  The punctuation tokens are:
# with
# poise ======> True
#
#
#  The punctuation tokens are:
# poise
# and ======> True
#
#
#  The punctuation tokens are:
# and
# comfort ======> True
#
#
#  The punctuation tokens are:
# comfort
# . ======> False
#
#
#  The punctuation tokens are:
# While ======> False
#
#
#  The punctuation tokens are:
# the ======> True
#
#
#  The punctuation tokens are:
# the
# economy ======> True
#
#
#  The punctuation tokens are:
# economy
# has ======> True
#
#
#  The punctuation tokens are:
# has
# welcomed ======> True
#
#
#  The punctuation tokens are:
# welcomed
# international ======> True
#
#
#  The punctuation tokens are:
# international
# companies ======> True
#
#
#  The punctuation tokens are:
# companies
# to ======> True
#
#
#  The punctuation tokens are:
# to
# invest ======> True
#
#
#  The punctuation tokens are:
# invest
# in ======> True
#
#
#  The punctuation tokens are:
# in
# it ======> True
#
#
#  The punctuation tokens are:
# it
# with ======> True
#
#
#  The punctuation tokens are:
# with
# open ======> True
#
#
#  The punctuation tokens are:
# open
# arms ======> True
#
#
#  The punctuation tokens are:
# arms
# since ======> True
#
#
#  The punctuation tokens are:
# since
# liberalisation ======> True
#
#
#  The punctuation tokens are:
# liberalisation
# in ======> True
#
#
#  The punctuation tokens are:
# in
# the ======> True
#
#
#  The punctuation tokens are:
# the
# 1990s ======> True
#
#
#  The punctuation tokens are:
# 1990s
# , ======> False
#
#
#  The punctuation tokens are:
# Indians ======> False
#
#
#  The punctuation tokens are:
# have ======> True
#
#
#  The punctuation tokens are:
# have
# been ======> True
#
#
#  The punctuation tokens are:
# been
# prudent ======> True
#
#
#  The punctuation tokens are:
# prudent
# and ======> True
#
#
#  The punctuation tokens are:
# and
# proactive ======> True
#
#
#  The punctuation tokens are:
# proactive
# in ======> True
#
#
#  The punctuation tokens are:
# in
# adopting ======> True
#
#
#  The punctuation tokens are:
# adopting
# global ======> True
#
#
#  The punctuation tokens are:
# global
# approaches ======> True
#
#
#  The punctuation tokens are:
# approaches
# and ======> True
#
#
#  The punctuation tokens are:
# and
# skills ======> True
#
#
#  The punctuation tokens are:
# skills
# . ======> False
#
#
#  The punctuation tokens are:
# Indian ======> False
#
#
#  The punctuation tokens are:
# villagers ======> True
#
#
#  The punctuation tokens are:
# villagers
# have ======> True
#
#
#  The punctuation tokens are:
# have
# proudly ======> True
#
#
#  The punctuation tokens are:
# proudly
# taken ======> True
#
#
#  The punctuation tokens are:
# taken
# up ======> True
#
#
#  The punctuation tokens are:
# up
# farming ======> True
#
#
#  The punctuation tokens are:
# farming
# , ======> False
#
#
#  The punctuation tokens are:
# advanced ======> True
#
#
#  The punctuation tokens are:
# advanced
# agriculture ======> True
#
#
#  The punctuation tokens are:
# agriculture
# and ======> True
#
#
#  The punctuation tokens are:
# and
# unique ======> True
#
#
#  The punctuation tokens are:
# unique
# handicrafts ======> True
#
#
#  The punctuation tokens are:
# handicrafts
# as ======> True
#
#
#  The punctuation tokens are:
# as
# their ======> True
#
#
#  The punctuation tokens are:
# their
# profession ======> True
#
#
#  The punctuation tokens are:
# profession
# on ======> True
#
#
#  The punctuation tokens are:
# on
# one ======> True
#
#
#  The punctuation tokens are:
# one
# hand ======> True
#
#
#  The punctuation tokens are:
# hand
# , ======> False
#
#
#  The punctuation tokens are:
# while ======> True
#
#
#  The punctuation tokens are:
# while
# the ======> True
#
#
#  The punctuation tokens are:
# the
# modern ======> True
#
#
#  The punctuation tokens are:
# modern
# industries ======> True
#
#
#  The punctuation tokens are:
# industries
# and ======> True
#
#
#  The punctuation tokens are:
# and
# professional ======> True
#
#
#  The punctuation tokens are:
# professional
# services ======> True
#
#
#  The punctuation tokens are:
# services
# sectors ======> True
#
#
#  The punctuation tokens are:
# sectors
# are ======> True
#
#
#  The punctuation tokens are:
# are
# coming ======> True
#
#
#  The punctuation tokens are:
# coming
# up ======> True
#
#
#  The punctuation tokens are:
# up
# in ======> True
#
#
#  The punctuation tokens are:
# in
# a ======> True
#
#
#  The punctuation tokens are:
# a
# big ======> True
#
#
#  The punctuation tokens are:
# big
# way ======> True
#
#
#  The punctuation tokens are:
# way
# on ======> True
#
#
#  The punctuation tokens are:
# on
# the ======> True
#
#
#  The punctuation tokens are:
# the
# other ======> True
#
#
#  The punctuation tokens are:
# other
# . ======> False
#
#
#  The punctuation tokens are:
# Thus ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> True
#
#
#  The punctuation tokens are:
# the
# country ======> True
#
#
#  The punctuation tokens are:
# country
# is ======> True
#
#
#  The punctuation tokens are:
# is
# attracting ======> True
#
#
#  The punctuation tokens are:
# attracting
# many ======> True
#
#
#  The punctuation tokens are:
# many
# global ======> True
#
#
#  The punctuation tokens are:
# global
# majors ======> True
#
#
#  The punctuation tokens are:
# majors
# for ======> True
#
#
#  The punctuation tokens are:
# for
# strategic ======> True
#
#
#  The punctuation tokens are:
# strategic
# investments ======> True
#
#
#  The punctuation tokens are:
# investments
# owing ======> True
#
#
#  The punctuation tokens are:
# owing
# to ======> True
#
#
#  The punctuation tokens are:
# to
# the ======> True
#
#
#  The punctuation tokens are:
# the
# presence ======> True
#
#
#  The punctuation tokens are:
# presence
# of ======> True
#
#
#  The punctuation tokens are:
# of
# a ======> True
#
#
#  The punctuation tokens are:
# a
# vast ======> True
#
#
#  The punctuation tokens are:
# vast
# range ======> True
#
#
#  The punctuation tokens are:
# range
# of ======> True
#
#
#  The punctuation tokens are:
# of
# industries ======> True
#
#
#  The punctuation tokens are:
# industries
# , ======> False
#
#
#  The punctuation tokens are:
# investment ======> True
#
#
#  The punctuation tokens are:
# investment
# avenues ======> True
#
#
#  The punctuation tokens are:
# avenues
# and ======> True
#
#
#  The punctuation tokens are:
# and
# a ======> True
#
#
#  The punctuation tokens are:
# a
# supportive ======> True
#
#
#  The punctuation tokens are:
# supportive
# Government ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# A ======> False
#
#
#  The punctuation tokens are:
# huge ======> True
#
#
#  The punctuation tokens are:
# huge
# population ======> True
#
#
#  The punctuation tokens are:
# population
# , ======> False
#
#
#  The punctuation tokens are:
# mostly ======> True
#
#
#  The punctuation tokens are:
# mostly
# comprising ======> True
#
#
#  The punctuation tokens are:
# comprising
# the ======> True
#
#
#  The punctuation tokens are:
# the
# youth ======> True
#
#
#  The punctuation tokens are:
# youth
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> True
#
#
#  The punctuation tokens are:
# is
# a ======> True
#
#
#  The punctuation tokens are:
# a
# strong ======> True
#
#
#  The punctuation tokens are:
# strong
# driver ======> True
#
#
#  The punctuation tokens are:
# driver
# for ======> True
#
#
#  The punctuation tokens are:
# for
# demand ======> True
#
#
#  The punctuation tokens are:
# demand
# and ======> True
#
#
#  The punctuation tokens are:
# and
# an ======> True
#
#
#  The punctuation tokens are:
# an
# ample ======> True
#
#
#  The punctuation tokens are:
# ample
# source ======> True
#
#
#  The punctuation tokens are:
# source
# of ======> True
#
#
#  The punctuation tokens are:
# of
# manpower ======> True
#
#
#  The punctuation tokens are:
# manpower
#
#  The total non-punctuation words are: 165

# %% [markdown]
# ### Checking for upper case

# %%
# Count of upper case tokens

up_count = 0
for token in doc_1:
    print (token, '======>', token.is_upper)
    print ('\n \n The punctuation tokens are:')
    if token.is_upper == True:
        up_count = up_count + 1
        print (token)
print ('\n The total non-punctuation words are:', up_count)
# Out:
# India ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# South ======> False
#
#
#  The punctuation tokens are:
# Asian ======> False
#
#
#  The punctuation tokens are:
# nation ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# seventh ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# largest ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# by ======> False
#
#
#  The punctuation tokens are:
# area ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# second ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# over ======> False
#
#
#  The punctuation tokens are:
# 1.38 ======> False
#
#
#  The punctuation tokens are:
# billion ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# democracy ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# world ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# India ======> False
#
#
#  The punctuation tokens are:
# boasts ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# immensely ======> False
#
#
#  The punctuation tokens are:
# rich ======> False
#
#
#  The punctuation tokens are:
# cultural ======> False
#
#
#  The punctuation tokens are:
# heritage ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# including ======> False
#
#
#  The punctuation tokens are:
# numerous ======> False
#
#
#  The punctuation tokens are:
# languages ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# traditions ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# The ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# holds ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# uniqueness ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# diversity ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# hence ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# adapted ======> False
#
#
#  The punctuation tokens are:
# itself ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# changes ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# poise ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# comfort ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# While ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# economy ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# welcomed ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# companies ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# invest ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# it ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# open ======> False
#
#
#  The punctuation tokens are:
# arms ======> False
#
#
#  The punctuation tokens are:
# since ======> False
#
#
#  The punctuation tokens are:
# liberalisation ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# 1990s ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# Indians ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# been ======> False
#
#
#  The punctuation tokens are:
# prudent ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# proactive ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# adopting ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# approaches ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# skills ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Indian ======> False
#
#
#  The punctuation tokens are:
# villagers ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# proudly ======> False
#
#
#  The punctuation tokens are:
# taken ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# farming ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# advanced ======> False
#
#
#  The punctuation tokens are:
# agriculture ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# unique ======> False
#
#
#  The punctuation tokens are:
# handicrafts ======> False
#
#
#  The punctuation tokens are:
# as ======> False
#
#
#  The punctuation tokens are:
# their ======> False
#
#
#  The punctuation tokens are:
# profession ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# one ======> False
#
#
#  The punctuation tokens are:
# hand ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# while ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# modern ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# professional ======> False
#
#
#  The punctuation tokens are:
# services ======> False
#
#
#  The punctuation tokens are:
# sectors ======> False
#
#
#  The punctuation tokens are:
# are ======> False
#
#
#  The punctuation tokens are:
# coming ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# big ======> False
#
#
#  The punctuation tokens are:
# way ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# other ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Thus ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# attracting ======> False
#
#
#  The punctuation tokens are:
# many ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# majors ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# strategic ======> False
#
#
#  The punctuation tokens are:
# investments ======> False
#
#
#  The punctuation tokens are:
# owing ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# presence ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# vast ======> False
#
#
#  The punctuation tokens are:
# range ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# investment ======> False
#
#
#  The punctuation tokens are:
# avenues ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# supportive ======> False
#
#
#  The punctuation tokens are:
# Government ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# A ======> True
#
#
#  The punctuation tokens are:
# A
# huge ======> False
#
#
#  The punctuation tokens are:
# population ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# mostly ======> False
#
#
#  The punctuation tokens are:
# comprising ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# youth ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# strong ======> False
#
#
#  The punctuation tokens are:
# driver ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# demand ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# ample ======> False
#
#
#  The punctuation tokens are:
# source ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# manpower ======> False
#
#
#  The punctuation tokens are:
#
#  The total non-punctuation words are: 1

# %% [markdown]
# ### Checking for title case tokens

# %%
# Count of title case tokens

t_count = 0
for token in doc_1:
    print (token, '======>', token.is_title)
    print ('\n \n The punctuation tokens are:')
    if token.is_title == True:
        t_count = t_count + 1
        print (token)
print ('\n The total non-punctuation words are:', t_count)
# Out:
# India ======> True
#
#
#  The punctuation tokens are:
# India
# , ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# South ======> True
#
#
#  The punctuation tokens are:
# South
# Asian ======> True
#
#
#  The punctuation tokens are:
# Asian
# nation ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# seventh ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# largest ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# by ======> False
#
#
#  The punctuation tokens are:
# area ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# second ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# over ======> False
#
#
#  The punctuation tokens are:
# 1.38 ======> False
#
#
#  The punctuation tokens are:
# billion ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# democracy ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# world ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# India ======> True
#
#
#  The punctuation tokens are:
# India
# boasts ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# immensely ======> False
#
#
#  The punctuation tokens are:
# rich ======> False
#
#
#  The punctuation tokens are:
# cultural ======> False
#
#
#  The punctuation tokens are:
# heritage ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# including ======> False
#
#
#  The punctuation tokens are:
# numerous ======> False
#
#
#  The punctuation tokens are:
# languages ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# traditions ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# The ======> True
#
#
#  The punctuation tokens are:
# The
# country ======> False
#
#
#  The punctuation tokens are:
# holds ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# uniqueness ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# diversity ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# hence ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# adapted ======> False
#
#
#  The punctuation tokens are:
# itself ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# changes ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# poise ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# comfort ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# While ======> True
#
#
#  The punctuation tokens are:
# While
# the ======> False
#
#
#  The punctuation tokens are:
# economy ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# welcomed ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# companies ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# invest ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# it ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# open ======> False
#
#
#  The punctuation tokens are:
# arms ======> False
#
#
#  The punctuation tokens are:
# since ======> False
#
#
#  The punctuation tokens are:
# liberalisation ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# 1990s ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# Indians ======> True
#
#
#  The punctuation tokens are:
# Indians
# have ======> False
#
#
#  The punctuation tokens are:
# been ======> False
#
#
#  The punctuation tokens are:
# prudent ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# proactive ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# adopting ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# approaches ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# skills ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Indian ======> True
#
#
#  The punctuation tokens are:
# Indian
# villagers ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# proudly ======> False
#
#
#  The punctuation tokens are:
# taken ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# farming ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# advanced ======> False
#
#
#  The punctuation tokens are:
# agriculture ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# unique ======> False
#
#
#  The punctuation tokens are:
# handicrafts ======> False
#
#
#  The punctuation tokens are:
# as ======> False
#
#
#  The punctuation tokens are:
# their ======> False
#
#
#  The punctuation tokens are:
# profession ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# one ======> False
#
#
#  The punctuation tokens are:
# hand ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# while ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# modern ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# professional ======> False
#
#
#  The punctuation tokens are:
# services ======> False
#
#
#  The punctuation tokens are:
# sectors ======> False
#
#
#  The punctuation tokens are:
# are ======> False
#
#
#  The punctuation tokens are:
# coming ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# big ======> False
#
#
#  The punctuation tokens are:
# way ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# other ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Thus ======> True
#
#
#  The punctuation tokens are:
# Thus
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# attracting ======> False
#
#
#  The punctuation tokens are:
# many ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# majors ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# strategic ======> False
#
#
#  The punctuation tokens are:
# investments ======> False
#
#
#  The punctuation tokens are:
# owing ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# presence ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# vast ======> False
#
#
#  The punctuation tokens are:
# range ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# investment ======> False
#
#
#  The punctuation tokens are:
# avenues ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# supportive ======> False
#
#
#  The punctuation tokens are:
# Government ======> True
#
#
#  The punctuation tokens are:
# Government
# . ======> False
#
#
#  The punctuation tokens are:
# A ======> True
#
#
#  The punctuation tokens are:
# A
# huge ======> False
#
#
#  The punctuation tokens are:
# population ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# mostly ======> False
#
#
#  The punctuation tokens are:
# comprising ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# youth ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# strong ======> False
#
#
#  The punctuation tokens are:
# driver ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# demand ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# ample ======> False
#
#
#  The punctuation tokens are:
# source ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# manpower ======> False
#
#
#  The punctuation tokens are:
#
#  The total non-punctuation words are: 11

# %% [markdown]
# ### Checking for quote tokens

# %%
# Count of quote tokens

q_count = 0
for token in doc_1:
    print (token, '======>', token.is_quote)
    print ('\n \n The punctuation tokens are:')
    if token.is_quote == True:
        q_count = q_count + 1
        print (token)
print ('\n The total non-punctuation words are:', q_count)
# Out:
# India ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# South ======> False
#
#
#  The punctuation tokens are:
# Asian ======> False
#
#
#  The punctuation tokens are:
# nation ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# seventh ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# largest ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# by ======> False
#
#
#  The punctuation tokens are:
# area ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# second ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# over ======> False
#
#
#  The punctuation tokens are:
# 1.38 ======> False
#
#
#  The punctuation tokens are:
# billion ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# democracy ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# world ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# India ======> False
#
#
#  The punctuation tokens are:
# boasts ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# immensely ======> False
#
#
#  The punctuation tokens are:
# rich ======> False
#
#
#  The punctuation tokens are:
# cultural ======> False
#
#
#  The punctuation tokens are:
# heritage ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# including ======> False
#
#
#  The punctuation tokens are:
# numerous ======> False
#
#
#  The punctuation tokens are:
# languages ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# traditions ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# The ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# holds ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# uniqueness ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# diversity ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# hence ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# adapted ======> False
#
#
#  The punctuation tokens are:
# itself ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# changes ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# poise ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# comfort ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# While ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# economy ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# welcomed ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# companies ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# invest ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# it ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# open ======> False
#
#
#  The punctuation tokens are:
# arms ======> False
#
#
#  The punctuation tokens are:
# since ======> False
#
#
#  The punctuation tokens are:
# liberalisation ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# 1990s ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# Indians ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# been ======> False
#
#
#  The punctuation tokens are:
# prudent ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# proactive ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# adopting ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# approaches ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# skills ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Indian ======> False
#
#
#  The punctuation tokens are:
# villagers ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# proudly ======> False
#
#
#  The punctuation tokens are:
# taken ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# farming ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# advanced ======> False
#
#
#  The punctuation tokens are:
# agriculture ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# unique ======> False
#
#
#  The punctuation tokens are:
# handicrafts ======> False
#
#
#  The punctuation tokens are:
# as ======> False
#
#
#  The punctuation tokens are:
# their ======> False
#
#
#  The punctuation tokens are:
# profession ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# one ======> False
#
#
#  The punctuation tokens are:
# hand ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# while ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# modern ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# professional ======> False
#
#
#  The punctuation tokens are:
# services ======> False
#
#
#  The punctuation tokens are:
# sectors ======> False
#
#
#  The punctuation tokens are:
# are ======> False
#
#
#  The punctuation tokens are:
# coming ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# big ======> False
#
#
#  The punctuation tokens are:
# way ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# other ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Thus ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# attracting ======> False
#
#
#  The punctuation tokens are:
# many ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# majors ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# strategic ======> False
#
#
#  The punctuation tokens are:
# investments ======> False
#
#
#  The punctuation tokens are:
# owing ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# presence ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# vast ======> False
#
#
#  The punctuation tokens are:
# range ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# investment ======> False
#
#
#  The punctuation tokens are:
# avenues ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# supportive ======> False
#
#
#  The punctuation tokens are:
# Government ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# A ======> False
#
#
#  The punctuation tokens are:
# huge ======> False
#
#
#  The punctuation tokens are:
# population ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# mostly ======> False
#
#
#  The punctuation tokens are:
# comprising ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# youth ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# strong ======> False
#
#
#  The punctuation tokens are:
# driver ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# demand ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# ample ======> False
#
#
#  The punctuation tokens are:
# source ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# manpower ======> False
#
#
#  The punctuation tokens are:
#
#  The total non-punctuation words are: 0

# %% [markdown]
# ### Checking for bracket tokens

# %%
# Count of bracket tokens

b_count = 0
for token in doc_1:
    print (token, '======>', token.is_bracket)
    print ('\n \n The punctuation tokens are:')
    if token.is_bracket == True:
        b_count = b_count + 1
        print (token)
print ('\n The total non-punctuation words are:', b_count)
# Out:
# India ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# South ======> False
#
#
#  The punctuation tokens are:
# Asian ======> False
#
#
#  The punctuation tokens are:
# nation ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# seventh ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# largest ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# by ======> False
#
#
#  The punctuation tokens are:
# area ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# second ======> False
#
#
#  The punctuation tokens are:
# - ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# over ======> False
#
#
#  The punctuation tokens are:
# 1.38 ======> False
#
#
#  The punctuation tokens are:
# billion ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# democracy ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# world ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# India ======> False
#
#
#  The punctuation tokens are:
# boasts ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# immensely ======> False
#
#
#  The punctuation tokens are:
# rich ======> False
#
#
#  The punctuation tokens are:
# cultural ======> False
#
#
#  The punctuation tokens are:
# heritage ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# including ======> False
#
#
#  The punctuation tokens are:
# numerous ======> False
#
#
#  The punctuation tokens are:
# languages ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# traditions ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# The ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# holds ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# uniqueness ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# diversity ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# hence ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# adapted ======> False
#
#
#  The punctuation tokens are:
# itself ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# changes ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# poise ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# comfort ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# While ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# economy ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# welcomed ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# companies ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# invest ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# it ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# open ======> False
#
#
#  The punctuation tokens are:
# arms ======> False
#
#
#  The punctuation tokens are:
# since ======> False
#
#
#  The punctuation tokens are:
# liberalisation ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# 1990s ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# Indians ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# been ======> False
#
#
#  The punctuation tokens are:
# prudent ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# proactive ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# adopting ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# approaches ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# skills ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Indian ======> False
#
#
#  The punctuation tokens are:
# villagers ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# proudly ======> False
#
#
#  The punctuation tokens are:
# taken ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# farming ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# advanced ======> False
#
#
#  The punctuation tokens are:
# agriculture ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# unique ======> False
#
#
#  The punctuation tokens are:
# handicrafts ======> False
#
#
#  The punctuation tokens are:
# as ======> False
#
#
#  The punctuation tokens are:
# their ======> False
#
#
#  The punctuation tokens are:
# profession ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# one ======> False
#
#
#  The punctuation tokens are:
# hand ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# while ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# modern ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# professional ======> False
#
#
#  The punctuation tokens are:
# services ======> False
#
#
#  The punctuation tokens are:
# sectors ======> False
#
#
#  The punctuation tokens are:
# are ======> False
#
#
#  The punctuation tokens are:
# coming ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# big ======> False
#
#
#  The punctuation tokens are:
# way ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# other ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Thus ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# attracting ======> False
#
#
#  The punctuation tokens are:
# many ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# majors ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# strategic ======> False
#
#
#  The punctuation tokens are:
# investments ======> False
#
#
#  The punctuation tokens are:
# owing ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# presence ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# vast ======> False
#
#
#  The punctuation tokens are:
# range ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# investment ======> False
#
#
#  The punctuation tokens are:
# avenues ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# supportive ======> False
#
#
#  The punctuation tokens are:
# Government ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# A ======> False
#
#
#  The punctuation tokens are:
# huge ======> False
#
#
#  The punctuation tokens are:
# population ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# mostly ======> False
#
#
#  The punctuation tokens are:
# comprising ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# youth ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# strong ======> False
#
#
#  The punctuation tokens are:
# driver ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# demand ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# ample ======> False
#
#
#  The punctuation tokens are:
# source ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# manpower ======> False
#
#
#  The punctuation tokens are:
#
#  The total non-punctuation words are: 0

# %% [markdown]
# ### Checking for a number

# %%
# Count of number tokens

n_count = 0
for token in doc_1:
    print (token, '======>', token.like_num)
    print ('\n \n The punctuation tokens are:')
    if token.like_num == True:
        n_count = n_count + 1
        print (token)
        
print ('\n The total non-punctuation words are:', n_count)
# Out:
# India ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# South ======> False
#
#
#  The punctuation tokens are:
# Asian ======> False
#
#
#  The punctuation tokens are:
# nation ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# seventh ======> True
#
#
#  The punctuation tokens are:
# seventh
# - ======> False
#
#
#  The punctuation tokens are:
# largest ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# by ======> False
#
#
#  The punctuation tokens are:
# area ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# second ======> True
#
#
#  The punctuation tokens are:
# second
# - ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# over ======> False
#
#
#  The punctuation tokens are:
# 1.38 ======> True
#
#
#  The punctuation tokens are:
# 1.38
# billion ======> True
#
#
#  The punctuation tokens are:
# billion
# people ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# most ======> False
#
#
#  The punctuation tokens are:
# populous ======> False
#
#
#  The punctuation tokens are:
# democracy ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# world ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# India ======> False
#
#
#  The punctuation tokens are:
# boasts ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# immensely ======> False
#
#
#  The punctuation tokens are:
# rich ======> False
#
#
#  The punctuation tokens are:
# cultural ======> False
#
#
#  The punctuation tokens are:
# heritage ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# including ======> False
#
#
#  The punctuation tokens are:
# numerous ======> False
#
#
#  The punctuation tokens are:
# languages ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# traditions ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# people ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# The ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# holds ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# uniqueness ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# its ======> False
#
#
#  The punctuation tokens are:
# diversity ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# hence ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# adapted ======> False
#
#
#  The punctuation tokens are:
# itself ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# changes ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# poise ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# comfort ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# While ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# economy ======> False
#
#
#  The punctuation tokens are:
# has ======> False
#
#
#  The punctuation tokens are:
# welcomed ======> False
#
#
#  The punctuation tokens are:
# international ======> False
#
#
#  The punctuation tokens are:
# companies ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# invest ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# it ======> False
#
#
#  The punctuation tokens are:
# with ======> False
#
#
#  The punctuation tokens are:
# open ======> False
#
#
#  The punctuation tokens are:
# arms ======> False
#
#
#  The punctuation tokens are:
# since ======> False
#
#
#  The punctuation tokens are:
# liberalisation ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# 1990s ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# Indians ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# been ======> False
#
#
#  The punctuation tokens are:
# prudent ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# proactive ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# adopting ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# approaches ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# skills ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Indian ======> False
#
#
#  The punctuation tokens are:
# villagers ======> False
#
#
#  The punctuation tokens are:
# have ======> False
#
#
#  The punctuation tokens are:
# proudly ======> False
#
#
#  The punctuation tokens are:
# taken ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# farming ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# advanced ======> False
#
#
#  The punctuation tokens are:
# agriculture ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# unique ======> False
#
#
#  The punctuation tokens are:
# handicrafts ======> False
#
#
#  The punctuation tokens are:
# as ======> False
#
#
#  The punctuation tokens are:
# their ======> False
#
#
#  The punctuation tokens are:
# profession ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# one ======> True
#
#
#  The punctuation tokens are:
# one
# hand ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# while ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# modern ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# professional ======> False
#
#
#  The punctuation tokens are:
# services ======> False
#
#
#  The punctuation tokens are:
# sectors ======> False
#
#
#  The punctuation tokens are:
# are ======> False
#
#
#  The punctuation tokens are:
# coming ======> False
#
#
#  The punctuation tokens are:
# up ======> False
#
#
#  The punctuation tokens are:
# in ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# big ======> False
#
#
#  The punctuation tokens are:
# way ======> False
#
#
#  The punctuation tokens are:
# on ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# other ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# Thus ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# country ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# attracting ======> False
#
#
#  The punctuation tokens are:
# many ======> False
#
#
#  The punctuation tokens are:
# global ======> False
#
#
#  The punctuation tokens are:
# majors ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# strategic ======> False
#
#
#  The punctuation tokens are:
# investments ======> False
#
#
#  The punctuation tokens are:
# owing ======> False
#
#
#  The punctuation tokens are:
# to ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# presence ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# vast ======> False
#
#
#  The punctuation tokens are:
# range ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# industries ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# investment ======> False
#
#
#  The punctuation tokens are:
# avenues ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# supportive ======> False
#
#
#  The punctuation tokens are:
# Government ======> False
#
#
#  The punctuation tokens are:
# . ======> False
#
#
#  The punctuation tokens are:
# A ======> False
#
#
#  The punctuation tokens are:
# huge ======> False
#
#
#  The punctuation tokens are:
# population ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# mostly ======> False
#
#
#  The punctuation tokens are:
# comprising ======> False
#
#
#  The punctuation tokens are:
# the ======> False
#
#
#  The punctuation tokens are:
# youth ======> False
#
#
#  The punctuation tokens are:
# , ======> False
#
#
#  The punctuation tokens are:
# is ======> False
#
#
#  The punctuation tokens are:
# a ======> False
#
#
#  The punctuation tokens are:
# strong ======> False
#
#
#  The punctuation tokens are:
# driver ======> False
#
#
#  The punctuation tokens are:
# for ======> False
#
#
#  The punctuation tokens are:
# demand ======> False
#
#
#  The punctuation tokens are:
# and ======> False
#
#
#  The punctuation tokens are:
# an ======> False
#
#
#  The punctuation tokens are:
# ample ======> False
#
#
#  The punctuation tokens are:
# source ======> False
#
#
#  The punctuation tokens are:
# of ======> False
#
#
#  The punctuation tokens are:
# manpower ======> False
#
#
#  The punctuation tokens are:
#
#  The total non-punctuation words are: 5

# %% [markdown]
# ### Checking for URL token

# %%
doc_4 = nlp('The website for NMIMS is www.nmims.edu.in')

# %%
u_count = 0
for token in doc_4:
    print (token, '=====>', token.like_url)
    if token.like_url == True:
        u_count = u_count + 1
print ("\n The no of URL tokens in the doc is:", u_count)
# Out:
# The =====> False
# website =====> False
# for =====> False
# NMIMS =====> False
# is =====> False
# www.nmims.edu.in =====> True
#
#  The no of URL tokens in the doc is: 1

# %% [markdown]
# ### Checking for email token

# %%
doc_5 = nlp('My email id is abinash_mishra001@nmims.edu.in')

# %%
# Checking for email token

e_count = 0
for token in doc_5:
    print (token, '=====>', token.like_email)
    if token.like_email == True:
        e_count = e_count + 1
        
print ("\n The no of email tokens in the doc is:", e_count)
# Out:
# My =====> False
# email =====> False
# i =====> False
# d =====> False
# is =====> False
# abinash_mishra001@nmims.edu.in =====> True
#
#  The no of email tokens in the doc is: 1

# %% [markdown]
# ### Parts of Speech - POS

# %%
doc_2
# Out:
# 10000 is a big number

# %%
for token in doc_2:
    print (token, '===>', token.pos_) #pos_ shows the Parts of Speech, while pos shows the position of the token.
# Out:
# 10000 ===> NUM
# is ===> AUX
# a ===> DET
# big ===> ADJ
# number ===> NOUN

# %% [markdown]
# ### Converting into a Dataframe

# %%
spacy.explain('AUX') # This provides some details about the POS
# Out:
# 'auxiliary'

# %%
spacy.explain('ADJ')
# Out:
# 'adjective'

# %%
cols = ['Token', 'POS', 'Explain_POS', 'TAG', 'Explain_TAG']
cols
# Out:
# ['Token', 'POS', 'Explain_POS', 'TAG', 'Explain_TAG']

# %%
rows = []
for token in doc_1:
    row = token, token.pos_, spacy.explain(token.pos_), token.tag_, spacy.explain(token.tag_)
    rows.append(row)
rows
# Out:
# [(India, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (South,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (Asian,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (nation, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (is, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (seventh, 'ADV', 'adverb', 'RB', 'adverb'),
#  (-, 'PUNCT', 'punctuation', 'HYPH', 'punctuation mark, hyphen'),
#  (largest, 'ADJ', 'adjective', 'JJS', 'adjective, superlative'),
#  (country, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (by, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (area, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (second, 'ADV', 'adverb', 'RB', 'adverb'),
#  (-, 'PUNCT', 'punctuation', 'HYPH', 'punctuation mark, hyphen'),
#  (most, 'ADV', 'adverb', 'RBS', 'adverb, superlative'),
#  (populous,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (country, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (with,
#   'ADP',
#   'adposition',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (over,
#   'ADP',
#   'adposition',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (1.38, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (billion, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (people, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (most, 'ADV', 'adverb', 'RBS', 'adverb, superlative'),
#  (populous,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (democracy, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (world, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (India, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (boasts, 'VERB', 'verb', 'VBZ', 'verb, 3rd person singular present'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (an, 'DET', 'determiner', 'DT', 'determiner'),
#  (immensely, 'ADV', 'adverb', 'RB', 'adverb'),
#  (rich,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (cultural,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (heritage, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (including, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (numerous,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (languages, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (traditions, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (people, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (The, 'DET', 'determiner', 'DT', 'determiner'),
#  (country, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (holds, 'VERB', 'verb', 'VBZ', 'verb, 3rd person singular present'),
#  (its, 'PRON', 'pronoun', 'PRP$', 'pronoun, possessive'),
#  (uniqueness, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (its, 'PRON', 'pronoun', 'PRP$', 'pronoun, possessive'),
#  (diversity, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (hence, 'ADV', 'adverb', 'RB', 'adverb'),
#  (has, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (adapted, 'VERB', 'verb', 'VBN', 'verb, past participle'),
#  (itself, 'PRON', 'pronoun', 'PRP', 'pronoun, personal'),
#  (to, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (international,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (changes, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (with,
#   'ADP',
#   'adposition',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (poise, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (comfort, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (While,
#   'SCONJ',
#   'subordinating conjunction',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (economy, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (has, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (welcomed, 'VERB', 'verb', 'VBN', 'verb, past participle'),
#  (international,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (companies, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (to, 'PART', 'particle', 'TO', 'infinitival "to"'),
#  (invest, 'VERB', 'verb', 'VB', 'verb, base form'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (it, 'PRON', 'pronoun', 'PRP', 'pronoun, personal'),
#  (with,
#   'ADP',
#   'adposition',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (open,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (arms, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (since,
#   'SCONJ',
#   'subordinating conjunction',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (liberalisation, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (1990s, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (Indians, 'PROPN', 'proper noun', 'NNPS', 'noun, proper plural'),
#  (have, 'AUX', 'auxiliary', 'VBP', 'verb, non-3rd person singular present'),
#  (been, 'AUX', 'auxiliary', 'VBN', 'verb, past participle'),
#  (prudent,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (proactive,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (adopting, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (global,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (approaches, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (skills, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (Indian,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (villagers, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (have, 'AUX', 'auxiliary', 'VBP', 'verb, non-3rd person singular present'),
#  (proudly, 'ADV', 'adverb', 'RB', 'adverb'),
#  (taken, 'VERB', 'verb', 'VBN', 'verb, past participle'),
#  (up, 'ADP', 'adposition', 'RP', 'adverb, particle'),
#  (farming, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (advanced,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (agriculture, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (unique,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (handicrafts, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (as, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (their, 'PRON', 'pronoun', 'PRP$', 'pronoun, possessive'),
#  (profession, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (on, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (one, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (hand, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (while,
#   'SCONJ',
#   'subordinating conjunction',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (modern,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (industries, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (professional,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (services, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (sectors, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (are, 'AUX', 'auxiliary', 'VBP', 'verb, non-3rd person singular present'),
#  (coming, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (up, 'ADP', 'adposition', 'RP', 'adverb, particle'),
#  (in, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (big,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (way, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (on, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (other,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (Thus, 'ADV', 'adverb', 'RB', 'adverb'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (country, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (is, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (attracting, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (many,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (global,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (majors, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (for, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (strategic,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (investments, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (owing, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (to, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (presence, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (vast,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (range, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (industries, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (investment, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (avenues, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (supportive,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (Government, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (A, 'DET', 'determiner', 'DT', 'determiner'),
#  (huge,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (population, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (mostly, 'ADV', 'adverb', 'RB', 'adverb'),
#  (comprising, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (youth, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (is, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (strong,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (driver, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (for, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (demand, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (an, 'DET', 'determiner', 'DT', 'determiner'),
#  (ample,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (source, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (manpower, 'NOUN', 'noun', 'NN', 'noun, singular or mass')]

# %%
import pandas as pd

# %%
token_df = pd.DataFrame(rows, columns = cols)
token_df
# Out:
#         Token    POS  Explain_POS  TAG  \
# 0       India  PROPN  proper noun  NNP
# 1           ,  PUNCT  punctuation    ,
# 2           a    DET   determiner   DT
# 3       South    ADJ    adjective   JJ
# 4       Asian    ADJ    adjective   JJ
# ..        ...    ...          ...  ...
# 195        an    DET   determiner   DT
# 196     ample    ADJ    adjective   JJ
# 197    source   NOUN         noun   NN
# 198        of    ADP   adposition   IN
# 199  manpower   NOUN         noun   NN
#
#                                            Explain_TAG
# 0                                noun, proper singular
# 1                              punctuation mark, comma
# 2                                           determiner
# 3    adjective (English), other noun-modifier (Chin...
# 4    adjective (English), other noun-modifier (Chin...
# ..                                                 ...
# 195                                         determiner
# 196  adjective (English), other noun-modifier (Chin...
# 197                             noun, singular or mass
# 198          conjunction, subordinating or preposition
# 199                             noun, singular or mass
#
# [200 rows x 5 columns]

# %%
# Count of each POS

token_df['POS'].value_counts()
# Out:
# NOUN     48
# ADJ      29
# ADP      24
# PUNCT    23
# DET      20
# VERB     12
# CCONJ    10
# AUX       9
# ADV       9
# PRON      5
# NUM       4
# PROPN     3
# SCONJ     3
# PART      1
# Name: POS, dtype: int64
